# %%
import openai
from bia_tischi._utilities import available_models
from bia_tischi._machinery import init_assistant
from bia_tischi._machinery import Context

Context.verbose = True
init_assistant("gpt-3.5-turbo", 0)
# Out:
# Assistant initialised.
#
# You can call it using the %ai command, e.g.
#
# %ai please generate a random 2D grayscale image.

# %%
Context.verbose = False
# %ai please generate a random 2D grayscale image.
# Out:
# #### Assistant response
#
# To generate a random 2D grayscale image, we can use the `numpy` and `matplotlib` libraries.
#
# Here is the code to generate a random 2D grayscale image:
# #### Additional information
#
# Full input prompt: 280 token, 0.041999999999999996 US Cent.
#
# Full response: 141 token, 0.028200000000000003 US Cent.
#
# Current pricing is available at https://openai.com/pricingThe code was put into the next cell.
#
# It is **your responsibility to carefully check it** before executing!

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a random 2D array of values between 0 and 255
image = np.random.randint(0, 256, size=(512, 512), dtype=np.uint8)

# Display the image
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
import skimage.util
import matplotlib.pyplot as plt

# Step 2: Generate a random 2D grayscale image
image_dimensions = (512, 512)
random_image = skimage.util.random_noise(image_dimensions)

# Step 3: Display the generated random image
plt.imshow(random_image, cmap='gray')
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random image with shape (n, m)
n = 256  # Number of rows
m = 256  # Number of columns
image = np.random.randint(0, 256, size=(n, m), dtype=np.uint8)

# Display the image
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# Save the image
plt.imsave('random_image.png', image, cmap='gray')

# %%
import numpy as np

# Generate a random 2D grayscale image
image = np.random.rand(256, 256)

# Display the image using matplotlib
import matplotlib.pyplot as plt
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %%
import openai
models = openai.Model.list()
models
# Out:
# <OpenAIObject list at 0x122e4cd10> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "id": "text-search-babbage-doc-001",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
#           "id": "modelperm-s9n5HnzbtVn7kNc5TIZWiCFS",
#           "object": "model_permission",
#           "created": 1695933794,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": true,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "text-search-babbage-doc-001",
#       "parent": null
#     },
#     {
#       "id": "curie-search-query",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
# ...

# %%
openai.
