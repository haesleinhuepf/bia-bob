# %%
import openai
from bia_tischi._utilities import available_models
from bia_tischi._machinery import init_assistant
from bia_tischi._machinery import Context

Context.verbose = True
init_assistant("gpt-3.5-turbo", 0)
# %ai please print hello world
# Out:
# Assistant initialised.
#
# You can call it using the %ai command, e.g.
#
# %ai please generate a random 2D grayscale image.
#
# System prompt:
#     If the request entails writing code, write concise professional bioimage analysis high-quality python code.
#     The code should be as short as possible.
#     If there are several ways to solve the task, chose the option with the least amount of code.
#     Preferably, use these python libraries numpy,pandas,scipy,skimage,sklearn,seaborn,matplotlib.
#     Show results and save them in variables.
#     The following variables are available: In,Out,openai
#     Do not set the values of the variables that are available.
#     The following functions are available: get_ipython,open,available_models,init_assistant,Context
#     A live python environment is available and the code you produce will be executed afterwards.
#
#     Before writing the code, provide a concise step-by-step plan
#     of what the code will be going to do.
# ...

# %%
print("Hello World")

# %%
# %ai great! please write code to generate a random image!
# Out:
# System prompt:
#     If the request entails writing code, write concise professional bioimage analysis high-quality python code.
#     The code should be as short as possible.
#     If there are several ways to solve the task, chose the option with the least amount of code.
#     Preferably, use these python libraries numpy,pandas,scipy,skimage,sklearn,seaborn,matplotlib.
#     Show results and save them in variables.
#     The following variables are available: In,Out,openai
#     Do not set the values of the variables that are available.
#     The following functions are available: get_ipython,open,available_models,init_assistant,Context
#     A live python environment is available and the code you produce will be executed afterwards.
#
#     Before writing the code, provide a concise step-by-step plan
#     of what the code will be going to do.
#     This plan must not contain any "`" characters and should be written in plain text.
#     Then print the code.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.random.randint(0, 256, (256, 256, 3), dtype=np.uint8)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# %ai please gaussian blur the image
# Out:
# System prompt:
#     If the request entails writing code, write concise professional bioimage analysis high-quality python code.
#     The code should be as short as possible.
#     If there are several ways to solve the task, chose the option with the least amount of code.
#     Preferably, use these python libraries numpy,pandas,scipy,skimage,sklearn,seaborn,matplotlib.
#     Show results and save them in variables.
#     The following variables are available: In,Out,openai,np,plt,image
#     Do not set the values of the variables that are available.
#     The following functions are available: get_ipython,open,available_models,init_assistant,Context
#     A live python environment is available and the code you produce will be executed afterwards.
#
#     Before writing the code, provide a concise step-by-step plan
#     of what the code will be going to do.
#     This plan must not contain any "`" characters and should be written in plain text.
#     Then print the code.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter

# Generate a random image
image = np.random.randint(0, 256, (256, 256, 3), dtype=np.uint8)

# Apply Gaussian blur
blurred_image = gaussian_filter(image, sigma=2)

# Display original and blurred images
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(image)
axs[0].axis('off')
axs[0].set_title('Original Image')
axs[1].imshow(blurred_image)
axs[1].axis('off')
axs[1].set_title('Blurred Image (Gaussian Filter)')
plt.tight_layout()
plt.show()

# %%
# %ai please threshold the blurred image, please do not write all code again, simply use the existing image
# Out:
# System prompt:
#     If the request entails writing code, write concise professional bioimage analysis high-quality python code.
#     The code should be as short as possible.
#     If there are several ways to solve the task, chose the option with the least amount of code.
#     Preferably, use these python libraries numpy,pandas,scipy,skimage,sklearn,seaborn,matplotlib.
#     Show results and save them in variables.
#     The following variables are available: In,Out,openai,np,plt,image,blurred_image,fig,axs
#     Do not set the values of the variables that are available.
#     The following functions are available: get_ipython,open,available_models,init_assistant,Context,gaussian_filter
#     A live python environment is available and the code you produce will be executed afterwards.
#
#     Before writing the code, provide a concise step-by-step plan
#     of what the code will be going to do.
# ...

# %%
from skimage.filters import threshold_otsu
from skimage import util

# Convert the blurred image to grayscale
gray_image = util.img_as_ubyte(blurred_image)

# Apply Otsu's thresholding
thresh = threshold_otsu(gray_image)
binary_image = gray_image > thresh

# Display the original, blurred, and thresholded images
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(image)
axs[0].axis('off')
axs[0].set_title('Original Image')
axs[1].imshow(blurred_image)
axs[1].axis('off')
axs[1].set_title('Blurred Image')
axs[2].imshow(binary_image, cmap='gray')
axs[2].axis('off')
axs[2].set_title('Thresholded Image')
plt.tight_layout()
plt.show()

binary_image
# Out:
# /var/folders/_3/4djzggg133j_952jrwhnx8900000gq/T/ipykernel_3592/2494251882.py:8: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (256, 256, 3) looks like that of an RGB image.
#   thresh = threshold_otsu(gray_image)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/mambaforge/envs/chat-gpt-jupyter/lib/python3.9/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/mambaforge/envs/chat-gpt-jupyter/lib/python3.9/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
# ...

# %%
# %%ai
# we got an error:
# File ~/mambaforge/envs/chat-gpt-jupyter/lib/python3.9/site-packages/matplotlib/image.py:207, in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     205 if resample is None:
#     206     resample = image_obj.get_resample()
# --> 207 _image.resample(data, out, transform,
#     208                 _interpd_[interpolation],
#     209                 resample,
#     210                 alpha,
#     211                 image_obj.get_filternorm(),
#     212                 image_obj.get_filterrad())
#     213 return out
# ValueError: Unsupported dtype
# Out:
# System prompt:
#     If the request entails writing code, write concise professional bioimage analysis high-quality python code.
#     The code should be as short as possible.
#     If there are several ways to solve the task, chose the option with the least amount of code.
#     Preferably, use these python libraries numpy,pandas,scipy,skimage,sklearn,seaborn,matplotlib.
#     Show results and save them in variables.
#     The following variables are available: In,Out,openai,np,plt,image,blurred_image,fig,axs,util,gray_image,thresh,binary_image
#     Do not set the values of the variables that are available.
#     The following functions are available: get_ipython,open,available_models,init_assistant,Context,gaussian_filter,threshold_otsu
#     A live python environment is available and the code you produce will be executed afterwards.
#
#     Before writing the code, provide a concise step-by-step plan
#     of what the code will be going to do.
# ...

# %%
from skimage.filters import threshold_otsu
from skimage import util
import cv2

# Convert the blurred image to grayscale
gray_image = util.img_as_ubyte(blurred_image)

# Apply Otsu's thresholding
thresh = threshold_otsu(gray_image)
binary_image = gray_image > thresh

# Convert binary image data type to uint8
binary_image = binary_image.astype(np.uint8)

# Display the original, blurred, and thresholded images
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(image)
axs[0].axis('off')
axs[0].set_title('Original Image')
axs[1].imshow(blurred_image)
axs[1].axis('off')
axs[1].set_title('Blurred Image')
axs[2].imshow(binary_image, cmap='gray')
axs[2].axis('off')
axs[2].set_title('Thresholded Image')
plt.tight_layout()
plt.show()

binary_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 from skimage.filters import threshold_otsu
#       2 from skimage import util
# ----> 3 import cv2
#       5 # Convert the blurred image to grayscale
#       6 gray_image = util.img_as_ubyte(blurred_image)
#
# ModuleNotFoundError: No module named 'cv2'
