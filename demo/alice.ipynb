# %%
from bia_bob import alice

# %%
# %%alice test_image
# draw a black-background image with about 3 big white blobs.
# The image is supposed do look like a fluorescence confocal microscopy image
# Out:
# Generated image is stored as `test_image`.

# %%
test_image
# Out:
# StackViewNDArray([[[ 0, 11, 15],
#                    [ 0,  0,  9],
#                    [ 0,  0,  7],
#                    ...,
#                    [ 0,  4,  8],
#                    [ 0,  1, 11],
#                    [ 0,  3,  4]],
#
#                   [[ 0,  5, 10],
#                    [ 0,  2,  7],
#                    [ 0,  0,  7],
#                    ...,
#                    [ 0,  3,  7],
#                    [ 0,  2,  7],
#                    [ 0,  0,  2]],
#
#                   [[ 0,  2,  8],
#                    [ 0,  1,  9],
#                    [ 0,  2, 10],
#                    ...,
#                    [ 0,  3,  9],
#                    [ 0,  2, 10],
#                    [ 0,  2, 10]],
#
#                   ...,
#
#                   [[ 0,  3, 10],
#                    [ 0,  2, 11],
#                    [ 0,  4, 11],
#                    ...,
#                    [ 0,  4, 10],
#                    [ 0,  5, 11],
#                    [ 0,  5, 10]],
#
# ...
