# %% [markdown]
# # Voice recognition + audio response
# Bob can also listen to commands, execute them and respond using voice. This is powered by the [SpeechRecognition](https://github.com/Uberi/speech_recognition#readme) and [gTTS](https://gtts.readthedocs.io/en/latest/) Python libraries.

# %%
from bia_bob import bob

from skimage.io import imread

# %%
image = imread('membranes.tif')

# %%
bob.initialize(globals())

# %% [markdown]
# Turn bob's voice on for responses.

# %%
bob.speak()

# %% [markdown]
# After executing the next cell, say to your microphone something like "Segment the image and show the results." Say "bye bye" to finish the conversation.

# %%
bob.listen(until_bye_bye=True)
# Out:
# Listening...
# You said: segment the Image and show the result
# StackViewNDArray([[ 6,  6,  6, ...,  0,  0,  0],
#                   [ 6,  6,  6, ...,  0,  0,  0],
#                   [ 6,  6,  6, ...,  0,  3,  3],
#                   ...,
#                   [ 0,  0,  0, ..., 55, 55, 55],
#                   [ 0,  0,  0, ..., 55, 55, 55],
#                   [ 0,  0,  0, ..., 55, 55, 55]])
# The image has been segmented and the result is shown as segmented_image.jpg.
# Listening...
# You said: segment the image again using the seed watershed algorithm
# StackViewNDArray([[ 5,  5,  5, ...,  3,  3,  3],
#                   [ 5,  5,  5, ...,  3,  3,  3],
#                   [ 5,  5,  5, ...,  3,  3,  3],
#                   ...,
#                   [24, 24, 24, ..., 27, 27, 27],
#                   [24, 24, 24, ..., 27, 27, 27],
#                   [24, 24, 24, ..., 27, 27, 27]])
# ...
