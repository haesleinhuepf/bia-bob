# %%
import numpy as np
from bia_tischi import tischi
tischi.__version__
# Out:
# '0.1.0'

# %%
tischi.initialize(globals())

# %%
# %%tischi
# please segment all nuclei in the blobs.tif grayscale image
# and show the resulting label mask
# Out:
# Plan:
#
# 1. First, we will load the image using skimage's 'imread' method.
# 2. Next, we will use the 'filters.otsu' function applied to the image to get the threshold value.
# 3. Using 'measure.label' function, we will identify distinct regions (nuclei).
# 4. Apply the label2rgb function to color-label the regions
# 5. Plot and show the resulting label mask using matplotlib.
#
# Unfortunately, the task cannot be started without setting the variable which loads the image. Anyway, let's move forward with writing bio-image analysis specific code.
#
# ```python
# # import required libraries
# import matplotlib.pyplot as plt
# from skimage import measure, filters, io, color
#
# # Step 1: load image
# image = io.imread('blobs.tif')
#
# # Step 2: apply otsu thresholding
# thresh = filters.threshold_otsu(image)
# binary_image = image > thresh
#
# # Step 3, 4: segment and color-label nuclei
# labels = measure.label(binary_image)
# image_label_overlay = color.label2rgb(labels, image=image)
#
# # Step 5: plot and show the label mask
# plt.imshow(image_label_overlay)
# plt.show()
# ```
#
# The above code identifies distinct regions (in our case nuclei) in a grayscale image and represents it as a label mask. Since this is a bioimage analysis related task, it assumes that blobs.tif is available and contains grayscale image of cells with nuclei distinguished from the surrounding cytoplasm by intensity.
#
# Please, note that for practical image segmentation other steps like noise filtering, intensity normalisation, morphological operations, edge detection might be required prior to thresholding and labelling.
#
# This platform doesn't seem to support executing Python code and it doesn't seem to have 'blobs.tif' file to input. The above code should be run in the proper Python environment with the supported libraries installed.
