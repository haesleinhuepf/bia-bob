# %% [markdown]
# # Tools with multiple inputs
# In this notebook we demonstrate how to call a tool that has multiple inputs such as a function that takes an image and a factor to multiply the image with the factor.

# %%
from bia_bob import bob
bob.__version__
# Out:
# '0.2.0'

# %%
# %bob Please load the image "blobs.tif" and show it.
# Out:
# StackViewNDArray([[ 40,  32,  24, ..., 216, 200, 200],
#                   [ 56,  40,  24, ..., 232, 216, 216],
#                   [ 64,  48,  24, ..., 240, 232, 232],
#                   ...,
#                   [ 72,  80,  80, ...,  48,  48,  48],
#                   [ 80,  80,  80, ...,  48,  48,  48],
#                   [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8)
# Here is the image "blobs.tif":

# %%
# %bob Please multiply the pixel values of blobs.tif by a factor of 2 and show the result
# Out:
# StackViewNDArray([[ 80,  64,  48, ..., 176, 144, 144],
#                   [112,  80,  48, ..., 208, 176, 176],
#                   [128,  96,  48, ..., 224, 208, 208],
#                   ...,
#                   [144, 160, 160, ...,  96,  96,  96],
#                   [160, 160, 160, ...,  96,  96,  96],
#                   [192, 176, 160, ...,  96,  96,  96]], dtype=uint8)
# Here is the result of multiplying the pixel values of "blobs.tif" by a factor of 2:
