# %% [markdown]
# # Using mistral / pixtral

# %%
from bia_bob import bob
bob.initialize(model="mistral-large-2411", vision_model="pixtral-12b-2409")
# Out:
#             <div style="font-size:7pt">
#             This notebook may contain text, code and images generated by artificial intelligence.
#             Used model: mistral-large-2411, vision model: pixtral-12b-2409, endpoint: None, bia-bob version: 0.25.0.. Do not enter sensitive or private information and verify generated contents according to good scientific practice. Read more: <a href="https://github.com/haesleinhuepf/bia-bob#disclaimer">https://github.com/haesleinhuepf/bia-bob#disclaimer</a>
#             </div>

# %%
import stackview
from skimage.io import imread

# Load the image
image = imread('c.png')

# Display the image
stackview.insight(image)
# Out:
# StackViewNDArray([[[  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    ...,
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255]],
#
#                   [[  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    ...,
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255]],
#
#                   [[  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    ...,
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255],
#                    [  0,   0,   0, 255]],
#
#                   ...,
#
#                   [[ 30,  45,  47, 255],
#                    [ 21,  36,  38, 255],
# ...

# %%
# %%bob image
# What is in this image? Answer in French.
# Out:
# L'image représente une tranche de fromage camembert avec de l'épaississement visible et un emballage en papier blanc autour, posé sur une surface sombre. À côté se trouve un pot rond, sans doute avec une étiquette indiquant "Châtelaire". Le fromage présente une texture moelleuse avec des lacunes, probablement causées par l'affinage.
