# %% [markdown]
# # Image Analysis using human language only
# In this notebook we will use English language only to analyze data.
# Under the hood, BiA-Bob will generate Python code and execute it.

# %%
open blobs.tif and show it
# Out:
# I will load the image `blobs.tif` and display it.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# import matplotlib.pyplot as plt
#
# # Load the image
# image = imread('blobs.tif')
#
# # Display the image
# plt.imshow(image, cmap='gray')
# plt.axis('off')  # Hide the axis
# plt_show()  # Use plt_show() as per instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
segment the image using Otsu's method
# Out:
# I will segment the image using Otsu's thresholding method.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# from skimage.filters import threshold_otsu
# import matplotlib.pyplot as plt
#
# # Load the image
# image = imread('blobs.tif')
#
# # Find Otsu's threshold value
# threshold_value = threshold_otsu(image)
#
# # Segment the image
# binary_image = image > threshold_value
#
# # Display the segmented image
# plt.imshow(binary_image, cmap='gray')
# plt.axis('off')  # Hide the axis
# plt_show()  # Use plt_show() as per instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
separate individual objects
# Out:
# I will separate individual objects in the segmented image using connected components labeling.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import label
# import matplotlib.pyplot as plt
#
# # Assuming 'binary_image' is the binary image obtained from Otsu's thresholding
#
# # Label the objects in the binary image
# label_image = label(binary_image)
#
# # Display the labeled image
# plt.imshow(label_image, cmap='nipy_spectral')
# plt.axis('off')  # Hide the axis
# plt_show()  # Use plt_show() as per instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
measure size and shape of the segmented objects, 
display results as dataframe
# Out:
# I will measure the size and shape properties of the segmented objects and display the results in a dataframe.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import regionprops
# import pandas as pd
#
# # Assuming 'label_image' is the labeled image from the connected components labeling
#
# # Measure properties of labeled objects
# properties = regionprops(label_image, image)
#
# # Extract size and shape properties
# object_data = [{
#     'label': prop.label,
#     'area': prop.area,
#     'eccentricity': prop.eccentricity,
#     'solidity': prop.solidity,
#     'orientation': prop.orientation
# } for prop in properties]
#
# # Create a dataframe
# df = pd.DataFrame(object_data)
#
# # Display the dataframe
# display(df)
#         </pre>
#         </details>
#     label  area  eccentricity  solidity  orientation
# 0       1   433      0.876649  0.881874    -0.445057
# 1       2   185      0.828189  0.968586    -1.518883
# 2       3   658      0.352060  0.977712    -0.151090
# 3       4   434      0.341084  0.973094    -0.513943
# 4       5   477      0.771328  0.977459    -0.045020
# ..    ...   ...           ...       ...          ...
# 59     60     1      0.000000  1.000000     0.785398
# 60     61    81      0.947745  0.952941    -1.565594
# 61     62    90      0.971003  0.947368    -1.547086
# 62     63    53      0.939695  0.929825     1.565945
# 63     64    49      0.974495  0.924528     1.548303
#
# [64 rows x 5 columns]

# %%
plot eccentricity against area
# Out:
# I will create a scatter plot with eccentricity on the x-axis and area on the y-axis using the data from the previously created dataframe.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# import seaborn as sns
#
# # Assuming 'df' is the dataframe containing the object properties
#
# # Create a scatter plot of eccentricity against area
# sns.scatterplot(data=df, x='eccentricity', y='area')
#
# # Display the plot
# plt_show()  # Use plt_show() as per instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>
