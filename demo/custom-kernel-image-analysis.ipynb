# %% [markdown]
# # Image Analysis using human language only
# In this notebook we will use English language only to analyze data.
# Under the hood, BiA-Bob will generate Python code and execute it.

# %%
open blobs.tif and show it
# Out:
# I will open the image file `blobs.tif` and display it.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# import matplotlib.pyplot as plt
#
# # Load the image
# image = imread('blobs.tif')
#
# # Display the image
# plt.imshow(image, cmap='gray')
# plt_show()
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
segment the image using Otsu's method
# Out:
# I will segment the image using Otsu's thresholding method.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# from skimage.filters import threshold_otsu
# import matplotlib.pyplot as plt
#
# # Load the image
# image = imread('blobs.tif')
#
# # Apply Otsu's thresholding
# thresh = threshold_otsu(image)
# binary = image > thresh
#
# # Display the segmented binary image
# plt.imshow(binary, cmap='gray')
# plt_show()
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
separate individual objects
# Out:
# I will separate individual objects in the segmented binary image using connected components labeling.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import label
# import matplotlib.pyplot as plt
#
# # Apply connected components labeling
# label_image = label(binary)
#
# # Display the labeled image
# plt.imshow(label_image, cmap='nipy_spectral')
# plt_show()
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
measure size and shape of the segmented objects, 
display results as dataframe
# Out:
# I will measure the size and shape properties of the segmented objects and display the results as a dataframe.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import regionprops_table
# import pandas as pd
#
# # Measure properties of labeled objects
# properties = regionprops_table(label_image, properties=('label', 'area', 'perimeter', 'eccentricity', 'solidity'))
#
# # Create a dataframe to hold the properties
# df = pd.DataFrame(properties)
#
# # Display the dataframe
# display(df)
#         </pre>
#         </details>
#     label  area  perimeter  eccentricity  solidity
# 0       1   433  91.254834      0.876649  0.881874
# 1       2   185  53.556349      0.828189  0.968586
# 2       3   658  95.698485      0.352060  0.977712
# 3       4   434  76.870058      0.341084  0.973094
# 4       5   477  83.798990      0.771328  0.977459
# ..    ...   ...        ...           ...       ...
# 59     60     1   0.000000      0.000000  1.000000
# 60     61    81  40.727922      0.947745  0.952941
# 61     62    90  46.278175      0.971003  0.947368
# 62     63    53  31.899495      0.939695  0.929825
# 63     64    49  34.485281      0.974495  0.924528
#
# [64 rows x 5 columns]

# %%
plot eccentricity against area
# Out:
# I will create a plot with eccentricity on the x-axis and area on the y-axis using the previously measured properties of the segmented objects.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# import matplotlib.pyplot as plt
#
# # Plot eccentricity against area
# plt.scatter(df['eccentricity'], df['area'])
# plt.xlabel('Eccentricity')
# plt.ylabel('Area')
# plt.title('Eccentricity vs Area')
# plt_show()
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>
