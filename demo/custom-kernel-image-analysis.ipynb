# %% [markdown]
# # Image Analysis using human language only
# In this notebook we will use English language only to analyze data.
# Under the hood, BiA-Bob will generate Python code and execute it.

# %%
open blobs.tif and show it
# Out:
# To open the image file `blobs.tif` and display it, we will follow these steps:
#
# 1. Import the necessary library for reading the image.
# 2. Load the image from the file `blobs.tif`.
# 3. Display the image using the `display()` function.
#
# Now, let's write the code to perform these steps.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# import matplotlib.pyplot as plt
#
# # Step 1: Load the image
# image = imread('blobs.tif')
#
# # Step 2: Display the image
# plt.imshow(image, cmap='gray')
# plt.axis('off')  # Hide the axis to better visualize the image
# plt_show()  # Use plt_show() as per the instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
segment the image using Otsu's method
# Out:
# To segment the image using Otsu's method, we will follow these steps:
#
# 1. Import the necessary libraries for thresholding and displaying the image.
# 2. Load the image from the file `blobs.tif` if it's not already loaded.
# 3. Apply Otsu's thresholding method to find the optimal threshold value.
# 4. Segment the image by applying the threshold, creating a binary image.
# 5. Display the original image and the segmented binary image side by side for comparison.
#
# Now, let's write the code to perform these steps.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.io import imread
# from skimage.filters import threshold_otsu
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Step 1: Load the image if not already loaded
# # Assuming 'image' variable is already available from previous step
# # If not, uncomment the following line:
# # image = imread('blobs.tif')
#
# # Step 2: Apply Otsu's thresholding
# thresh = threshold_otsu(image)
# binary = image > thresh
#
# # Step 3: Display the original and segmented images side by side
# fig, axes = plt.subplots(ncols=2, figsize=(10, 5))
# ax = axes.ravel()
#
# ax[0].imshow(image, cmap='gray')
# ax[0].set_title('Original Image')
# ax[0].axis('off')
#
# ax[1].imshow(binary, cmap='gray')
# ax[1].set_title("Segmented Image using Otsu's Method")
# ax[1].axis('off')
#
# plt_show()  # Use plt_show() as per the instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
separate individual objects
# Out:
# To separate individual objects in the segmented binary image, we will perform connected components labeling, which will assign a unique label to each connected object. Here are the steps:
#
# 1. Import the necessary library for connected components labeling.
# 2. Use the binary image obtained from Otsu's thresholding method.
# 3. Apply connected components labeling to the binary image to separate individual objects.
# 4. Display the labeled image where each object is represented by a different color.
#
# Let's write the code to perform these steps.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import label
# from skimage.color import label2rgb
# import matplotlib.pyplot as plt
#
# # Assuming 'binary' variable is already available from previous segmentation step
# # If not, uncomment the following lines to load the image and apply Otsu's thresholding:
# # from skimage.io import imread
# # from skimage.filters import threshold_otsu
# # image = imread('blobs.tif')
# # thresh = threshold_otsu(image)
# # binary = image > thresh
#
# # Step 1: Apply connected components labeling
# label_image = label(binary)
#
# # Step 2: Convert the labeled image to RGB for visualization
# image_label_overlay = label2rgb(label_image, image=image, bg_label=0)
#
# # Step 3: Display the labeled image
# fig, ax = plt.subplots(figsize=(8, 6))
# ax.imshow(image_label_overlay)
# ax.set_title('Labeled Objects')
# ax.axis('off')
#
# plt_show()  # Use plt_show() as per the instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>

# %%
measure size and shape of the segmented objects, 
display results as dataframe
# Out:
# To measure the size and shape of the segmented objects and display the results as a dataframe, we will follow these steps:
#
# 1. Import the necessary libraries for measuring region properties and creating a dataframe.
# 2. Use the labeled image obtained from the connected components labeling.
# 3. Measure region properties such as area, perimeter, and other shape descriptors for each labeled object.
# 4. Create a dataframe to store the measurements.
# 5. Display the dataframe using the `display()` function.
#
# Let's write the code to perform these steps.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# from skimage.measure import regionprops
# import pandas as pd
#
# # Assuming 'label_image' variable is already available from previous labeling step
# # If not, uncomment the following lines to load the image, apply Otsu's thresholding, and label the image:
# # from skimage.io import imread
# # from skimage.filters import threshold_otsu
# # from skimage.measure import label
# # image = imread('blobs.tif')
# # thresh = threshold_otsu(image)
# # binary = image > thresh
# # label_image = label(binary)
#
# # Step 1: Measure region properties
# properties = regionprops(label_image)
#
# # Step 2: Create a list to hold the measurements
# object_measurements = []
#
# # Step 3: Loop over each labeled object to get its measurements
# for prop in properties:
#     object_measurements.append({
#         'label': prop.label,
#         'area': prop.area,
#         'perimeter': prop.perimeter,
#         'eccentricity': prop.eccentricity,
#         'equivalent_diameter': prop.equivalent_diameter,
#         'major_axis_length': prop.major_axis_length,
#         'minor_axis_length': prop.minor_axis_length,
#         'orientation': prop.orientation
#     })
#
# # Step 4: Create a dataframe from the measurements
# df = pd.DataFrame(object_measurements)
#
# # Step 5: Display the dataframe
# display(df)
#         </pre>
#         </details>
#     label  area  perimeter  eccentricity  equivalent_diameter  major_axis_length  minor_axis_length  orientation
# 0       1   433  91.254834      0.876649            23.480049          34.957399          16.819060    -0.445057
# 1       2   185  53.556349      0.828189            15.347616          21.061417          11.803854    -1.518883
# 2       3   658  95.698485      0.352060            28.944630          30.212552          28.278264    -0.151090
# 3       4   434  76.870058      0.341084            23.507147          24.535398          23.064079    -0.513943
# 4       5   477  83.798990      0.771328            24.644173          31.162612          19.833058    -0.045020
# ..    ...   ...        ...           ...                  ...                ...                ...          ...
# 59     60     1   0.000000      0.000000             1.128379           0.000000           0.000000     0.785398
# 60     61    81  40.727922      0.947745            10.155413          18.558405           5.920690    -1.565594
# 61     62    90  46.278175      0.971003            10.704745          22.458271           5.369081    -1.547086
# 62     63    53  31.899495      0.939695             8.214724          14.811463           5.065719     1.565945
# 63     64    49  34.485281      0.974495             7.898654          17.127524           3.843548     1.548303
#
# [64 rows x 8 columns]

# %%
plot eccentricity against area
# Out:
# To plot eccentricity against area for the segmented objects, we will follow these steps:
#
# 1. Use the dataframe created from the previous step containing the measurements of the objects.
# 2. Plot the 'eccentricity' column on the x-axis and the 'area' column on the y-axis using matplotlib.
# 3. Label the axes and show the plot using `plt_show()`.
#
# Let's write the code to perform these steps.
#         <details>
#         <summary> Show code </summary>
#         <pre>
# import matplotlib.pyplot as plt
#
# # Assuming 'df' variable is already available from previous measurement step
# # If not, you would need to run the measurement code to obtain the dataframe
#
# # Step 1: Plot eccentricity against area
# plt.figure(figsize=(8, 6))
# plt.scatter(df['eccentricity'], df['area'])
# plt.title('Eccentricity vs. Area')
# plt.xlabel('Eccentricity')
# plt.ylabel('Area')
# plt.grid(True)
#
# # Step 2: Show the plot
# plt_show()  # Use plt_show() as per the instructions
#         </pre>
#         </details>
# <img src="data:image/png;base64,..."></img>
