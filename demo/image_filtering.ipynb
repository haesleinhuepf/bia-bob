# %% [markdown]
# # Filtering images
# BIA Bob knows about a small number of operations on images, such as removing noise, background and detecting edges.

# %%
from bia_bob import bob
bob.__version__
# Out:
# '0.2.0'

# %%
# %bob open blobs.tif and show it
# Out:
# StackViewNDArray([[ 40,  32,  24, ..., 216, 200, 200],
#                   [ 56,  40,  24, ..., 232, 216, 216],
#                   [ 64,  48,  24, ..., 240, 232, 232],
#                   ...,
#                   [ 72,  80,  80, ...,  48,  48,  48],
#                   [ 80,  80,  80, ...,  48,  48,  48],
#                   [ 96,  88,  80, ...,  48,  48,  48]], dtype=uint8)
# Here is the image "blobs.tif":

# %%
# %bob denoise the image and show the denoised image
# Out:
# StackViewNDArray([[0.1624657 , 0.1360645 , 0.10876053, ..., 0.86638097,
#                    0.82828095, 0.81064999],
#                   [0.18596637, 0.15246559, 0.11891377, ..., 0.89538532,
#                    0.8651058 , 0.85033477],
#                   [0.18871153, 0.15925827, 0.13081328, ..., 0.92286036,
#                    0.90080357, 0.88975777],
#                   ...,
#                   [0.29191605, 0.29932959, 0.30210685, ..., 0.18823656,
#                    0.18823823, 0.18823925],
#                   [0.32075942, 0.3183446 , 0.31297106, ..., 0.18823529,
#                    0.18823529, 0.18823529],
#                   [0.34830167, 0.33483175, 0.3195247 , ..., 0.18823529,
#                    0.18823529, 0.18823529]])
# Here is the denoised image:

# %%
# %bob denoise the image using the median filter and show the denoised image
# Out:
# StackViewNDArray([[ 40.,  32.,  24., ..., 216., 216., 200.],
#                   [ 48.,  40.,  24., ..., 232., 216., 216.],
#                   [ 48.,  40.,  32., ..., 240., 232., 232.],
#                   ...,
#                   [ 72.,  80.,  80., ...,  48.,  48.,  48.],
#                   [ 80.,  80.,  80., ...,  48.,  48.,  48.],
#                   [ 88.,  80.,  80., ...,  48.,  48.,  48.]])
# Here is the denoised image:

# %%
# %bob please remove the background in the image and show the resulting image
# Out:
# StackViewNDArray([[24., 16.,  8., ..., 16.,  0.,  0.],
#                   [40., 24.,  8., ..., 32., 16., 16.],
#                   [48., 32.,  8., ..., 40., 32., 32.],
#                   ...,
#                   [32., 40., 40., ...,  8.,  8.,  8.],
#                   [40., 40., 40., ...,  8.,  8.,  8.],
#                   [56., 48., 40., ...,  8.,  8.,  8.]])
# Here is the resulting image with the background removed:

# %%
# %bob please highlight edges in the image and show the resulting image
# Out:
# StackViewNDArray([[24., 32., 16., ..., 40., 32., 16.],
#                   [32., 40., 24., ..., 40., 40., 32.],
#                   [24., 40., 24., ..., 32., 24., 16.],
#                   ...,
#                   [16., 16.,  8., ...,  0.,  0.,  0.],
#                   [24., 24.,  8., ...,  0.,  0.,  0.],
#                   [16., 16.,  8., ...,  0.,  0.,  0.]])
# Here is the resulting image with the highlighted edges:
